# %%
import pandas as pd
import sys
import requests
import tweepy

# %% [markdown]
# # Connect to Twitter API

# %%
sys.path.insert(1, '../../')
import api as api_tok
api_key = api_tok.TWITTER_KEY
api_key_secret = api_tok.TWITTER_SEC
access_token = api_tok.TWITTER_TOKEN
access_token_secret = api_tok.TWITTER_SEC_TOKEN
# authenticate
auth = tweepy.OAuthHandler(api_key,api_key_secret)
auth.set_access_token(access_token,access_token_secret)

api = tweepy.API(auth)

# %% [markdown]
# # Get Tweets from a region

# %%
from geopy import geocoders

# %%
from geopy.geocoders import Nominatim
geolocator = Nominatim(user_agent="Tweet Region")

# %%
# search parameters
city = 'New York'
radius = '360km'

# %%
# locate with geocode
location = geolocator.geocode(city)
geocode = "{},{},{}".format(location.latitude, location.longitude,radius)

# %%
geocode
# Out:
# '40.7127281,-74.0060152,360km'

# %%
#columns = ['time','user','tweet']
data = []
hashtag = '*'
columns = ['id','datetime','screen_name','follower_count','tweet','hashtags','lang',
          'mentions_id','mentions_screen_name','reply_screen_name','reply_id']
for i,tweet in enumerate(tweepy.Cursor(api.search_tweets,q=hashtag,geocode=geocode,
                                       tweet_mode='extended').items(2000)):
    t_id = tweet.id
    t_created_at = tweet.created_at
    t_user_screen_name = tweet.user.screen_name
    t_user_followers_count = tweet.user.followers_count
    t_full_text = tweet.full_text
    t_hashtags = tweet.entities['hashtags']
    t_lang = tweet.lang
    
    user_mentions_id = [n['id'] for n in tweet.entities['user_mentions']]
    user_mentions_screen_name = [n['screen_name'] for n in tweet.entities['user_mentions']]
    reply_screen_name = tweet.in_reply_to_screen_name
    reply_user_id = tweet.in_reply_to_user_id
    
    data.append([t_id,t_created_at,t_user_screen_name,t_user_followers_count,
                t_full_text,t_hashtags,t_lang,
                user_mentions_id,user_mentions_screen_name,reply_screen_name,reply_user_id])
    df = pd.DataFrame(data, columns=columns)

#df = pd.DataFrame(data, columns=columns)
df.head()
# Out:
#                     id                  datetime    screen_name  \
# 0  1544241571113336832 2022-07-05 08:47:35+00:00  danielm052699
# 1  1544241570060578817 2022-07-05 08:47:35+00:00     Nyasan2024
# 2  1544241569632587776 2022-07-05 08:47:35+00:00   HaveNo_Name_
# 3  1544241569083056129 2022-07-05 08:47:35+00:00     marla_vous
# 4  1544241569070473217 2022-07-05 08:47:35+00:00     DispatchDc
#
#    follower_count                                              tweet hashtags  \
# 0              18                                    @Jessicazay1 🙌🏻       []
# 1              21              @CIXSANTY1 Your face is a big mistake       []
# 2             994  @masre963 لنطرنط مووش رفاهيه لنطرنط ضروره اساس...       []
# 3           12461                          👇 https://t.co/CezIMpwSg0       []
# 4              38  24 sec transmission\n7/5/2022 4:46:55 AM\nhttp...       []
#
#   lang            mentions_id mentions_screen_name reply_screen_name  \
# 0  und  [1543029027002372096]        [Jessicazay1]       Jessicazay1
# 1   en  [1400554403342528520]          [CIXSANTY1]         CIXSANTY1
# 2   ar            [267046460]           [masre963]          masre963
# 3  und                     []                   []              None
# 4   fr                     []                   []              None
#
#        reply_id
# 0  1.543029e+18
# 1  1.400554e+18
# 2  2.670465e+08
# 3           NaN
# 4           NaN

# %%
df.head()
# Out:
#                     id                  datetime    screen_name  \
# 0  1544241571113336832 2022-07-05 08:47:35+00:00  danielm052699
# 1  1544241570060578817 2022-07-05 08:47:35+00:00     Nyasan2024
# 2  1544241569632587776 2022-07-05 08:47:35+00:00   HaveNo_Name_
# 3  1544241569083056129 2022-07-05 08:47:35+00:00     marla_vous
# 4  1544241569070473217 2022-07-05 08:47:35+00:00     DispatchDc
#
#    follower_count                                              tweet hashtags  \
# 0              18                                    @Jessicazay1 🙌🏻       []
# 1              21              @CIXSANTY1 Your face is a big mistake       []
# 2             994  @masre963 لنطرنط مووش رفاهيه لنطرنط ضروره اساس...       []
# 3           12461                          👇 https://t.co/CezIMpwSg0       []
# 4              38  24 sec transmission\n7/5/2022 4:46:55 AM\nhttp...       []
#
#   lang            mentions_id mentions_screen_name reply_screen_name  \
# 0  und  [1543029027002372096]        [Jessicazay1]       Jessicazay1
# 1   en  [1400554403342528520]          [CIXSANTY1]         CIXSANTY1
# 2   ar            [267046460]           [masre963]          masre963
# 3  und                     []                   []              None
# 4   fr                     []                   []              None
#
#        reply_id
# 0  1.543029e+18
# 1  1.400554e+18
# 2  2.670465e+08
# 3           NaN
# 4           NaN

# %%
df.shape
# Out:
# (2000, 11)

# %% [markdown]
# # Process Collected Tweets

# %%
from nltk import word_tokenize
from nltk.corpus import stopwords  #stopwords
from nltk.stem import WordNetLemmatizer  
from sklearn.feature_extraction.text import TfidfVectorizer
import re
stop_words=set(stopwords.words('english'))

# %%
import spacy
spacy.load('en_core_web_sm')
from spacy.lang.en import English

# %%
# only keep english tweets
df = df[df['lang']=='en']

# %% [markdown]
# ## Tokenize w/ filters

# %%
from spacymoji import Emoji

# %%
nlp = spacy.load('en_core_web_sm')
emoji = Emoji(nlp)
nlp.add_pipe('emoji',first=True)
#emoj_tokens = nlp(" ".join(pos_emoji))
#parser = English()
def tokenize(tweet):
    filtered_tokens = []
    tokens = nlp(tweet)
    for token in tokens:
        if token.like_url: # nourls
            continue
        elif token.prefix_=="@": #no screen names
            continue
        elif token.prefix_=="#": #no hashtag
            continue
        elif token.is_punct: # no punctuations
            continue
        elif token.like_email: # no emails
            continue
        #elif token.is_stop: # no stopwords
        #    continue
        elif token._.is_emoji:
            continue
        elif token.is_space: # no space
            continue
        elif token.is_left_punct:
            continue
        elif token.is_right_punct:
            filtered.tokens.append(token.lower_[:-1])
        else:
            filtered_tokens.append(re.sub('[\W]','',token.lower_))
    return filtered_tokens

# %%
import nltk
#nltk.download('wordnet')
from nltk.corpus import wordnet as wn
def get_lemma(word):
    lemma = wn.morphy(word)
    if lemma is None:
        return word
    else:
        return lemma
    
from nltk.stem.wordnet import WordNetLemmatizer
def get_lemma2(word):
    return WordNetLemmatizer().lemmatize(word)

# %%
#nltk.download('stopwords')
en_stop = set(nltk.corpus.stopwords.words('english'))

# %%
def filter_tokens(text):
    tokens = tokenize(text)
    tokens = [token for token in tokens if len(token) > 2]
    #tokens = [token for token in tokens if token not in en_stop]
    #tokens = [get_lemma(token) for token in tokens]
    return tokens

# %%
tweet_tokens = []
for tweet in df.tweet.values:
    tokens = filter_tokens(tweet)
    #print(tweet)
    #print(tokens)
    tweet_tokens.append(tokens)

# %%
#tweet_tokens

# %%
df.head()
# Out:
#                      id                  datetime      screen_name  \
# 1   1544241570060578817 2022-07-05 08:47:35+00:00       Nyasan2024
# 6   1544241567917084672 2022-07-05 08:47:35+00:00        ty1da0220
# 7   1544241567464030208 2022-07-05 08:47:34+00:00  hamarpercussion
# 9   1544241567296282624 2022-07-05 08:47:34+00:00    __TJSfrenchie
# 10  1544241567166337025 2022-07-05 08:47:34+00:00  BeautyProtector
#
#     follower_count                                              tweet  \
# 1               21              @CIXSANTY1 Your face is a big mistake
# 6               14              @HereToClarify @nflrums Terrible take
# 7             1978  Under The Double Eagle - Download Sheet Music ...
# 9               90  @thickandbougie_ @KyleRichards I cant wait to ...
# 10             606  @ju_and_the_cats We have the same! 🖤 Does your...
#
#                                              hashtags lang  \
# 1                                                  []   en
# 6                                                  []   en
# 7   [{'text': 'hamarpercussion', 'indices': [144, ...   en
# 9          [{'text': 'RHOBH', 'indices': [242, 248]}]   en
# 10                                                 []   en
#
#                          mentions_id             mentions_screen_name  \
# 1              [1400554403342528520]                      [CIXSANTY1]
# 6   [1220208249221324802, 243097849]         [HereToClarify, nflrums]
# 7                        [266128933]                  [scoreexchange]
# 9             [4893242853, 65773523]  [thickandbougie_, KyleRichards]
# 10             [1498612664628621312]                [ju_and_the_cats]
#
#    reply_screen_name      reply_id
# 1          CIXSANTY1  1.400554e+18
# 6      HereToClarify  1.220208e+18
# 7               None           NaN
# 9    thickandbougie_  4.893243e+09
# 10   ju_and_the_cats  1.498613e+18

# %% [markdown]
# ## Make bigrams & trigrams

# %%
import gensim
import pyLDAvis
from gensim import corpora
from gensim.models import CoherenceModel
import pickle

# %%
# Build the bigram and trigram models
bigram = gensim.models.Phrases(tweet_tokens, min_count=1, threshold=0.00000001) # higher threshold fewer phrases.
trigram = gensim.models.Phrases(bigram[tweet_tokens], threshold=0.0000001)

# %%
# Faster way to get a sentence clubbed as a trigram/bigram
bigram_mod = gensim.models.phrases.Phraser(bigram)
trigram_mod = gensim.models.phrases.Phraser(trigram)

# %%
all_gram_tokens = []
# See trigram example
for i in range(len(tweet_tokens)):
    all_gram_tokens.append(trigram_mod[bigram_mod[tweet_tokens[i]]])

# %%
#all_gram_tokens

# %%
final_tokens = []
for tokens in all_gram_tokens:
    tokens = [token for token in tokens if len(token) > 3]
    tokens = [token for token in tokens if token not in en_stop]
    tokens = [get_lemma(token) for token in tokens]
    if len(tokens)==0:
        continue
    final_tokens.append(tokens)

# %%
#final_tokens

# %% [markdown]
# # LDA with gensim

# %%
NUM_TOPICS = 5

# %%
dictionary = corpora.Dictionary(final_tokens)
corpus = [dictionary.doc2bow(text) for text in final_tokens]
lda = gensim.models.ldamodel.LdaModel(corpus, num_topics = NUM_TOPICS, id2word=dictionary, passes=15)
topics = lda.print_topics(num_words=4)
for topic in topics:
    print(topic)
# Out:
# (0, '0.004*"just_posted" + 0.004*"take" + 0.003*"still" + 0.003*"good_morning"')
# (1, '0.012*"signal_100_profitability_based" + 0.012*"factor_100_learn_more" + 0.012*"trades_profit" + 0.007*"trading_ideas_awaiting_short"')
# (2, '0.007*"good" + 0.005*"thank_you" + 0.004*"time" + 0.003*"happy_birthday"')
# (3, '0.004*"know" + 0.004*"want" + 0.004*"need" + 0.003*"like"')
# (4, '0.012*"learn_more" + 0.009*"trading_ideas_awaiting_short" + 0.007*"factor" + 0.007*"trades_profit"')

# %% [markdown]
# # Range of Num Topics & log perplexity

# %%
scores = []
models = {}
for num_topics in range(3,11):
    #dictionary = corpora.Dictionary(tweet_tokens)
    #corpus = [dictionary.doc2bow(text) for text in tweet_tokens]
    lda = gensim.models.ldamodel.LdaModel(corpus, num_topics = num_topics, id2word=dictionary, passes=15)
    topics = lda.print_topics(num_words=4)
    print("======== NUM TOPICS: {} ==========".format(num_topics))
    for topic in topics:
        print(topic)
    models[num_topics] = lda
    perplexity_score = lda.log_perplexity(corpus)
    # Compute Coherence Score
    coherence_model_lda = CoherenceModel(model=lda, texts=final_tokens, dictionary=dictionary, coherence='c_v')
    coherence_score = coherence_model_lda.get_coherence()

    scores.append([num_topics,perplexity_score,coherence_score])
perplex_df = pd.DataFrame(scores,columns=['num_topics','perplexity','coherence'])
# Out:
# ======== NUM TOPICS: 3 ==========
# (0, '0.004*"trades_profit" + 0.004*"factor" + 0.004*"learn_more" + 0.004*"want"')
# (1, '0.004*"time" + 0.004*"good" + 0.003*"woman" + 0.003*"right"')
# (2, '0.007*"trading_ideas_awaiting_short" + 0.007*"signal_100_profitability_based" + 0.007*"factor_100_learn_more" + 0.007*"trades_profit"')
# ======== NUM TOPICS: 4 ==========
# (0, '0.014*"trades_profit" + 0.009*"trading_ideas_awaiting_short" + 0.009*"signal_100_profitability_based" + 0.009*"factor_100_learn_more"')
# (1, '0.004*"for_the" + 0.004*"like" + 0.003*"want" + 0.003*"think"')
# (2, '0.004*"time" + 0.003*"shit" + 0.003*"need" + 0.003*"life"')
# (3, '0.004*"love" + 0.004*"based_trades_profit_factor" + 0.004*"signal_profitability" + 0.004*"learn_more"')
# ======== NUM TOPICS: 5 ==========
# (0, '0.009*"good" + 0.005*"make" + 0.003*"want" + 0.003*"show"')
# (1, '0.005*"like" + 0.004*"take" + 0.004*"give" + 0.004*"just_posted"')
# (2, '0.005*"based_trades_profit_factor" + 0.005*"signal_profitability" + 0.005*"back" + 0.004*"learn_more"')
# (3, '0.003*"life" + 0.003*"think" + 0.003*"come" + 0.003*"woman"')
# (4, '0.017*"trades_profit" + 0.011*"factor_100_learn_more" + 0.011*"signal_100_profitability_based" + 0.010*"trading_ideas_awaiting_short"')
# ======== NUM TOPICS: 6 ==========
# (0, '0.005*"time" + 0.005*"come" + 0.004*"for_the" + 0.003*"still"')
# (1, '0.003*"like" + 0.003*"time" + 0.003*"life" + 0.003*"out_the"')
# (2, '0.019*"trades_profit" + 0.013*"factor_100_learn_more" + 0.013*"signal_100_profitability_based" + 0.012*"trading_ideas_awaiting_short"')
# (3, '0.006*"woman" + 0.004*"look" + 0.004*"back" + 0.003*"something"')
# (4, '0.004*"love" + 0.004*"ever" + 0.003*"good" + 0.003*"think"')
# (5, '0.007*"based_trades_profit_factor" + 0.007*"signal_profitability" + 0.006*"learn_more" + 0.006*"trading_ideas_awaiting_short"')
# ======== NUM TOPICS: 7 ==========
# (0, '0.005*"need" + 0.004*"take" + 0.004*"would" + 0.003*"like"')
# (1, '0.006*"good" + 0.006*"look" + 0.006*"like" + 0.005*"back"')
# (2, '0.006*"want" + 0.004*"start" + 0.003*"really" + 0.003*"people"')
# (3, '0.025*"trades_profit" + 0.016*"signal_100_profitability_based" + 0.016*"factor_100_learn_more" + 0.015*"trading_ideas_awaiting_short"')
# (4, '0.007*"signal_profitability" + 0.007*"based_trades_profit_factor" + 0.006*"learn_more" + 0.006*"trading_ideas_awaiting_short"')
# (5, '0.006*"happy_birthday" + 0.005*"well" + 0.004*"true" + 0.004*"life"')
# (6, '0.008*"love" + 0.005*"for_the" + 0.005*"woman" + 0.004*"still"')
# ======== NUM TOPICS: 8 ==========
# (0, '0.004*"someone" + 0.004*"life" + 0.004*"would" + 0.003*"time"')
# (1, '0.006*"want" + 0.005*"back" + 0.004*"like" + 0.004*"night"')
# (2, '0.008*"signal_profitability" + 0.008*"based_trades_profit_factor" + 0.008*"learn_more" + 0.007*"trading_ideas_awaiting_short"')
# (3, '0.006*"love" + 0.005*"like" + 0.005*"good_morning" + 0.004*"make"')
# (4, '0.010*"trades_profit" + 0.010*"factor" + 0.010*"learn_more" + 0.008*"profitability_based"')
# (5, '0.013*"good" + 0.006*"time" + 0.004*"give" + 0.004*"people"')
# (6, '0.019*"factor_100_learn_more" + 0.019*"signal_100_profitability_based" + 0.018*"trades_profit" + 0.011*"trading_ideas_awaiting_short"')
# (7, '0.006*"happy_birthday" + 0.005*"today" + 0.005*"need" + 0.004*"take"')
# ======== NUM TOPICS: 9 ==========
# (0, '0.010*"good" + 0.006*"thank_you" + 0.004*"back" + 0.004*"just_posted"')
# (1, '0.010*"signal_profitability" + 0.010*"based_trades_profit_factor" + 0.009*"learn_more" + 0.009*"trading_ideas_awaiting_short"')
# (2, '0.012*"learn_more" + 0.012*"factor" + 0.012*"trades_profit" + 0.009*"profitability_based"')
# (3, '0.006*"woman" + 0.005*"want" + 0.004*"morning" + 0.004*"know"')
# (4, '0.004*"say" + 0.003*"well" + 0.003*"life" + 0.003*"someone"')
# (5, '0.005*"good_morning" + 0.005*"like" + 0.004*"life" + 0.004*"baby"')
# (6, '0.008*"like" + 0.004*"want" + 0.003*"little" + 0.003*"donate"')
# (7, '0.020*"signal_100_profitability_based" + 0.020*"factor_100_learn_more" + 0.019*"trades_profit" + 0.011*"trading_ideas_awaiting_short"')
# (8, '0.005*"great" + 0.005*"country" + 0.004*"want" + 0.004*"good"')
# ======== NUM TOPICS: 10 ==========
# (0, '0.012*"good" + 0.008*"thank_you" + 0.005*"still" + 0.004*"could"')
# (1, '0.010*"based_trades_profit_factor" + 0.010*"signal_profitability" + 0.009*"learn_more" + 0.009*"trading_ideas_awaiting_short"')
# (2, '0.005*"want" + 0.004*"need" + 0.004*"another" + 0.004*"please"')
# (3, '0.006*"people" + 0.005*"really" + 0.004*"baby" + 0.004*"mind"')
# (4, '0.007*"time" + 0.005*"people" + 0.005*"life" + 0.005*"want"')
# (5, '0.011*"love" + 0.007*"for_the" + 0.005*"like" + 0.004*"much"')
# (6, '0.033*"trades_profit" + 0.022*"signal_100_profitability_based" + 0.022*"factor_100_learn_more" + 0.020*"trading_ideas_awaiting_short"')
# (7, '0.007*"back" + 0.006*"even" + 0.006*"life" + 0.005*"make"')
# (8, '0.005*"take" + 0.004*"face" + 0.004*"and_the" + 0.004*"great"')
# (9, '0.006*"good_morning" + 0.004*"right" + 0.004*"back" + 0.003*"thanks"')

# %%
perplex_df.sort_values('perplexity',ascending=False)
# Out:
#    num_topics  perplexity  coherence
# 0           3   -8.664973   0.541465
# 1           4   -8.729437   0.573384
# 2           5   -8.786625   0.565584
# 3           6   -8.838732   0.562020
# 4           7   -8.857806   0.585460
# 5           8   -8.904575   0.583024
# 6           9   -8.940614   0.574837
# 7          10   -8.944403   0.545815

# %%
perplex_df.sort_values('coherence',ascending=False)
# Out:
#    num_topics  perplexity  coherence
# 4           7   -8.857806   0.585460
# 5           8   -8.904575   0.583024
# 6           9   -8.940614   0.574837
# 1           4   -8.729437   0.573384
# 2           5   -8.786625   0.565584
# 3           6   -8.838732   0.562020
# 7          10   -8.944403   0.545815
# 0           3   -8.664973   0.541465

# %%
best_coherence = perplex_df.sort_values('coherence',ascending=True)['num_topics'].iloc[0]
best_coherence
# Out:
# 3

# %% [markdown]
# ### calculate model perplexity & coherency score

# %%
import pyLDAvis.gensim_models as gensimvis
lda_display = gensimvis.prepare(models[best_coherence], corpus, dictionary, sort_topics=False)
pyLDAvis.display(lda_display)
# Out:
# /Users/dannykang/opt/anaconda3/envs/webscrap/lib/python3.9/site-packages/pyLDAvis/_prepare.py:246: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   default_term_info = default_term_info.sort_values(
# /Users/dannykang/opt/anaconda3/envs/webscrap/lib/python3.9/site-packages/past/builtins/misc.py:45: DeprecationWarning: the imp module is deprecated in favour of importlib; see the module's documentation for alternative uses
#   from imp import reload
# /Users/dannykang/opt/anaconda3/envs/webscrap/lib/python3.9/site-packages/past/builtins/misc.py:45: DeprecationWarning: the imp module is deprecated in favour of importlib; see the module's documentation for alternative uses
#   from imp import reload
# /Users/dannykang/opt/anaconda3/envs/webscrap/lib/python3.9/site-packages/past/builtins/misc.py:45: DeprecationWarning: the imp module is deprecated in favour of importlib; see the module's documentation for alternative uses
#   from imp import reload
# /Users/dannykang/opt/anaconda3/envs/webscrap/lib/python3.9/site-packages/past/builtins/misc.py:45: DeprecationWarning: the imp module is deprecated in favour of importlib; see the module's documentation for alternative uses
#   from imp import reload
# /Users/dannykang/opt/anaconda3/envs/webscrap/lib/python3.9/site-packages/past/builtins/misc.py:45: DeprecationWarning: the imp module is deprecated in favour of importlib; see the module's documentation for alternative uses
#   from imp import reload
# /Users/dannykang/opt/anaconda3/envs/webscrap/lib/python3.9/site-packages/past/builtins/misc.py:45: DeprecationWarning: the imp module is deprecated in favour of importlib; see the module's documentation for alternative uses
#   from imp import reload
# <link rel="stylesheet" type="text/css" href="https://cdn.jsdelivr.net/gh/bmabey/pyLDAvis@3.3.1/pyLDAvis/js/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el999031402257966008809566200160"></div>
# <script type="text/javascript">
#
# var ldavis_el999031402257966008809566200160_data = {"mdsDat": {"x": [-0.017871910241858975, -0.08138953899315679, 0.09926144923501574], "y": [-0.10048353316240868, 0.06515311057447819, 0.03533042258793054], "topics": [1, 2, 3], "cluster": [1, 1, 1], "Freq": [33.07607681825794, 32.53519426258325, 34.388728919158815]}, "tinfo": {"Term": ["signal_100_profitability_based", "factor_100_learn_more", "trading_ideas_awaiting_short", "trades_profit", "factor", "love", "profitability_based", "signal_profitability", "based_trades_profit_factor", "learn_more", "trading_ideas_awaiting_buy", "happy_birthday", "time", "hell", "good", "happen", "going", "shit", "point", "discussions_psychology", "hire_your", "economics_business", "heart", "photo", "come", "woman", "just_posted", "need", "american", "photo_boxers", "factor", "profitability_based", "happen", "discussions_psychology", "hire_your", "economics_business", "hell", "photo_boxers", "signal_6667_profitability_based", "alright", "imagine", "signal", "clean", "dline_155", "essays_english", "computer_powerpoint", "proessaywriter5", "calculus_quizzes", "law_algebra", "statistics_music", "spss_algebra", "fund", "programming_political", "law_projects", "security", "science_accounting", "geometry_marketing", "math_finance", "magazine", "found", "going", "person", "team", "shit", "just_posted", "learn_more", "baby", "back", "try", "everyone", "want", "great", "game", "you_have", "morning", "trades_profit", "they_are", "like", "for_the", "feel", "look", "start", "mind", "trading_ideas_awaiting_buy", "could", "trading_ideas_awaiting_short", "take", "come", "life", "make", "photo", "want_the", "pepper", "morals", "brooklyn", "fence_products", "customer_hong", "chainlink_wiremeshfence", "chain_link", "container_for", "kong_email", "loading_the", "boston", "rescue", "one", "rainfall_outlook", "jul_809z", "risk_excessive", "wpc_issues", "john", "like_the", "bitch", "tuesday", "taking_down", "activist", "putin", "posting", "day_slight", "bomb", "paper", "pretty", "point", "time", "american", "that_the", "ukraine", "have_you", "post", "woman", "right", "thank_you", "good", "tweet", "still", "say", "move", "into_the", "simple", "someone", "instead", "never", "sleep", "want", "nowplaying", "vote", "you_are", "home", "today", "life", "help", "could", "need", "people", "for_the", "free", "start", "take", "look", "signal_100_profitability_based", "factor_100_learn_more", "signal_profitability", "based_trades_profit_factor", "happy_birthday", "sometimes", "hands", "heart", "question", "asongormovieforbeachwear", "high", "clear", "send", "shot", "though", "drink", "others", "trade_profit", "vocation", "pray", "incident", "definitely", "hello", "for_you", "wish", "the_last", "priest", "answer", "learn", "kinda", "love", "trading_ideas_awaiting_short", "house", "teach", "much", "thanks", "trades_profit", "trading_ideas_awaiting_buy", "happy", "need", "think", "anything", "like", "another", "lost", "learn_more", "good", "give", "and_the", "people", "make", "show", "come", "thing", "good_morning", "know", "please", "life"], "Freq": [24.0, 24.0, 31.0, 36.0, 14.0, 20.0, 11.0, 10.0, 10.0, 23.0, 19.0, 7.0, 20.0, 7.0, 24.0, 6.0, 12.0, 10.0, 8.0, 5.0, 5.0, 5.0, 6.0, 5.0, 12.0, 14.0, 8.0, 21.0, 7.0, 4.0, 13.742371381547644, 11.043952355381279, 6.308153936712009, 4.966842380207765, 4.9667727393648455, 4.966494937095277, 6.7889904685764355, 4.289458459317326, 4.2728238116359885, 3.612678472949909, 3.612579529675816, 3.6111699685710463, 4.174571998808599, 2.934271630825772, 2.9342057954933947, 2.934006006189938, 2.9339883105659172, 2.9339795578916705, 2.9339120100795495, 2.933858352380907, 2.9337407621051583, 2.933704419479482, 2.933648859025568, 2.933576554325269, 2.933467906999294, 2.9334230019748984, 2.9333895134821284, 2.933293424340942, 2.9288874042353754, 2.856398897777554, 9.091236058662268, 5.23128654667158, 4.330676705100202, 7.591313867174492, 6.361659034381949, 12.980199163576478, 6.423871520723117, 9.925388747 ...
